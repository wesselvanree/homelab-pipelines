# %% [markdown]
# # Inspect output

# %%
import polars as pl

from homelab_pipelines.utils.paths import Paths

# %%
result = pl.read_parquet(
    Paths.repo_root
    / "output"
    / "raw_bybit_prices_15min_weekly"
    / "BTCUSDT"
    / "2025-12-07.parquet"
)
result

# %%
result.describe()
